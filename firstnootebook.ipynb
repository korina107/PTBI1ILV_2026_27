# %%
print "hello world"
# Out:
#   Cell In[3], line 1
#     print "hello world"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %% [markdown]
# helps us to give a comment or something, to help us of

# %%
print("hello world")
# Out:
# hello world

# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ------- -------------------------------- 1.8/9.8 MB 9.9 MB/s eta 0:00:01
#    ------------------ --------------------- 4.5/9.8 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.8 MB 15.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 14.1 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    -------------- ------------------------- 4.5/12.7 MB 20.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.9/12.7 MB 21.4 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.7 MB 21.5 MB/s eta 0:00:01
#    ---------------------------------------- 12.7/12.7 MB 19.8 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
# ...

# %%
import pandas as pd

data = pd.read_csv("C:/Users/rinas/Downloads/primates_diet_genesymbols.tsv",sep="\t", header=0)
